# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
df_train = pd.read_csv('data5.csv')
feature_cols = ['GapRate', 'GapRateSqrt', 'MinTotal', 'PoolSize', 'Transportation', 'MiscFactor', 'Multiplier']
train_x = df_train.loc[:, feature_cols]
train_y = df_train.Month50Base
#sns.heatmap(train_x.corr(), annot=True)
df_test = pd.read_csv('data2022_1_csv.csv')
test_x = df_test.loc[:, feature_cols]
test_x.head(5)
# Out:
#     GapRate  GapRateSqrt  MinTotal  PoolSize  Transportation  MiscFactor  \
# 0  0.333333     0.577350     675.0    1016.0               1           0
# 1  0.388889     0.623610     806.4     304.0               1           0
# 2  0.338583     0.581879     927.1     265.0               1           1
# 3  0.000000     0.000000     385.0     118.0               1           1
# 4  0.397059     0.630126     544.0    1110.0               1           1
#
#    Multiplier
# 0        0.14
# 1        0.19
# 2        0.23
# 3        0.13
# 4        0.15

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train_x, train_y)
a = reg.predict(test_x)
#remove comments when you run 
for i in a:
    print (max(0,i))

# added super long print to enable copy-pasting
for _ in range(100):
    print ("")
#print (a)
# Out:
# 152.82508812701116
# 177.71734296321782
# 90.21883949868581
# 83.83086449138577
# 124.041267915331
# 220.176538185746
# 41.70102131687746
# 123.16415840570085
# 75.38543211186169
# 48.60218807703238
# 123.79030496420815
# 205.47298301566553
# 78.30039914070886
# 0
# 94.53528315338433
# 0

# %%
coef = ["%.2f" % i for i in reg.coef_]
for i in range(7):
    print (feature_cols[i], "\t", coef[i])

print (reg.get_params())
# Out:
# GapRate 	 510.57
# GapRateSqrt 	 -153.60
# MinTotal 	 -0.01
# PoolSize 	 -0.05
# Transportation 	 90.23
# MiscFactor 	 -43.54
# Multiplier 	 -632.73
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
reg.predict([[0, math.sqrt(0), 400, 352*1.3, 1, 0, 0.1]])
# Out:
# array([128.63553253])
